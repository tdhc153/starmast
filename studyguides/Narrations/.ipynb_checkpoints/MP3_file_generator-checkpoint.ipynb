# %%
rm -rf ~/.wdm #Clear the cache

# %%
# IT WORKS

# -------------------------------------------------------------------
# SCRIPT: Extracts and translates MathML equations
#
# DESCRIPTION:
# This script uses Selenium to extract visible text and MathML equations from the MathJax-rendered webpage.
# It replaces each math equation with a placeholder (e.g., [[MATH_0]]), converts the MathML to spoken math
# using the Speech Rule Engine (SRE) in Clearspeak mode, and outputs a final readable script with
# the math translated into natural language.
#
# OUTPUT FILES:
# - final_script_with_translated_math.txt: Text from the webpage with spoken math inserted
#
# REQUIREMENTS:
# - Python packages:
#     pip install selenium webdriver-manager 
#     pip install gtts
# - Google Chrome browser
# - Node.js installed from https://nodejs.org/
# - Speech Rule Engine (SRE):
#     npm install -g speech-rule-engine
#     Confirm SRE is installed using: which sre
# - Adjust path to SRE in the code if it's not globally available
# -------------------------------------------------------------------

# Imports
import time
import re
import os
import subprocess
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager

# Set up Headless Chrome WebDriver
options = webdriver.ChromeOptions()
options.add_argument("--headless") 
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage") 

# Automatically installs and uses the correct ChromeDriver
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# Loads the page
url = "https://starmast.org/studyguides/introtocomplexnumbers" # CHANGE THIS TO THE WEBPAGE OF THE GUIDE YOU WANT 
print(f"Opening {url}")
driver.get(url)
time.sleep(10) # Wait for MathJax to finish rendering

# Wait for MathJax to finish rendering
# Makes sure all math has rendered before continuing
driver.execute_script("return MathJax.startup.promise")

# This replaces MathML with numbered unique placeholders: [[MATH_0]], [[MATH_1]], etc.
# and stores the original MathML in a list for later translation
mathml_list = driver.execute_script("""
  const mathElements = Array.from(document.querySelectorAll("mjx-container, script[type^='math/']"));
  const mathList = [];

  mathElements.forEach((el, index) => {
    const placeholderText = `[[MATH_${index}]]`;
    const placeholderNode = document.createTextNode(placeholderText);
    el.parentNode.replaceChild(placeholderNode, el);
    mathList.push(el.outerHTML);
  });

  return mathList;
""")

# This extracts readable content from headings, paragraphs, list items, callouts, and metadata
# Filters out nested duplicates to avoid repeated content
script_parts = driver.execute_script("""
  const tags = Array.from(document.querySelectorAll("p, li, h1, h2, h3, div.callout-title-container.flex-fill, div.title, div.quarto-title-meta-heading, div.quarto-title-meta-content, div.abstract, div.summary, div.quarto-category, span.author, div.author, div.abstract-title, div.categories"));

  const uniqueTags = tags.filter((el, i, arr) => {
    return !arr.some(otherEl => otherEl !== el && otherEl.contains(el));
  });

  const output = [];
  uniqueTags.forEach(el => {
    const text = el.innerText.trim();
    if (text) output.push(text);
  });

  return output;
""")


# Closes the browser
driver.quit()

# Sets up PATH to include Node + SRE location
# Note: May need to adjust this based on system and where `sre` is installed
os.environ["PATH"] += os.pathsep + "/Users/tom/node_modules/speech-rule-engine/bin"  # Update this path if needed
sre_path = "/Users/tom/node_modules/speech-rule-engine/bin/sre"  # Replace with output from `which sre`

# This converts Each MathML Entry into Spoken Math Using SRE (Clearspeak)
spoken_math = []
for i, mathml in enumerate(mathml_list):
    try:
        # Extracts the core MathML from within assistive markup
        mathml_clean = mathml.split('<mjx-assistive-mml')[1].split('</mjx-assistive-mml>')[0]  # Extract MathML portion

        # Uses subprocess to run SRE with Clearspeak
        result = subprocess.run(
            [sre_path, "--speech", "--domain", "clearspeak"],
            input=mathml_clean.encode("utf-8"),  # Pass the MathML as input to SRE
            capture_output=True
        )

        # Get the spoken output
        spoken = result.stdout.decode("utf-8").strip()  # Get the spoken math output
        if spoken:
            spoken_math.append(spoken)  
        else:
            spoken_math.append("(Empty output)")  
    except Exception as e:
        # Log errors if conversion fails
        spoken_math.append(f"(Error: {e})") 

# Replace placeholders with translated spoken math
final_script = []
for part in script_parts:
    for i, spoken in enumerate(spoken_math):
        # Replace each placeholder with the corresponding translated spoken math
        part = part.replace(f"[[MATH_{i}]]", spoken)
    final_script.append(part)

# Save the final script with spoken math
with open("final_script_with_translated_math.txt", "w", encoding="utf-8") as f:
    f.write("\n\n".join(final_script))

print("Done!")

# Open the file to read the script
with open("final_script_with_translated_math.txt", "r", encoding="utf-8") as f:
    script = f.read()

# Define the start and end markers
start_marker = "Introduction to complex numbers" # CHANGE THIS TO THE TITLE OF THE GUIDE
end_marker = "Version history" # CHANGE THIS TO THE QUESTIONS AT THE END OF FURTHER READING

# Use regex to find the content between the start and end markers
pattern = re.compile(rf"{re.escape(start_marker)}(.*?){re.escape(end_marker)}", re.DOTALL)

# Search for the content between the markers
match = pattern.search(script)

# Check if a match was found
if match:
    extracted_content = match.group(0)  # Get the matched content
    
    # Export to a new txt file
    with open("text.txt", "w", encoding="utf-8") as output_file: # CHANGE THIS ACCORDING TO THE GUIDE NAME
        output_file.write(extracted_content)  # Write the content to the file
    
    print("Content successfully extracted and saved to 'text.txt'.")
else:
    print("No matching content found.")

# If you want to print the script to check for errors 
with open("text.txt", "r", encoding="utf-8") as f:
    script = f.read()

print(script)
# Out:
# Opening https://starmast.org/studyguides/introtocomplexnumbers
# Done!
# Content successfully extracted and saved to 'text.txt'.
# Introduction to complex numbers
#
# KEY SKILLS
#
# ALGEBRA
#
# COMPLEX NUMBERS
#
# AUTHOR
#
# Tom Coleman
#
# SUMMARY
# Complex numbers are an extremely important concept in mathematics, as you can express a solution to any algebraic equation using complex numbers. This guide introduces the idea of a complex number in the form z equals a plus b i, as well as the concepts of real and imaginary parts, complex conjugates, and Argand diagrams.
#
# What is a complex number?
#
# Real numbers, which consist of all possible decimal numbers, can do lots of things very well. For instance, you can measure all possible lengths using real numbers, which you cannot do using rational numbers a divided by b with a comma b whole numbers and b non-zero. You can also solve any equation a x equals b for x, with a comma b non-zero real numbers.
#
# But real numbers cannot do everything. Consider the equation x squared equals negative 1 period Since the square of any real number is greater than or equal to 0, it follows that this equation has no solutions which are real numbers. So you will have to look elsewhere for the solution to such an equation; perhaps defining a new kind of number. Setting i to be a number such that i squared equals negative 1 solves this issue; this i is known as the imaginary unit.
#
# It turns out that introducing this imaginary unit i is enough to express solutions to all equations involving an x squared term, known as quadratic equations; for more on these, see Guide: Introduction to quadratic equations. By using this imaginary unit as the basis for a new number system containing the real numbers, you can solve all possible quadratic equations. This number system is known as the complex numbers.
#
# Complex numbers appear almost everywhere in mathematics. Aside from being used to solve any quadratic equation, they have important applications in the theory of numbers more generally, in higher forms of algebra, the study of functions, the theory of electromagnetism, solving differential equations, and even measuring the motion of tornadoes!
#
# This guide will focus on introducing the concept of a complex number, with the exact definition of complex numbers together with some initial examples of complex numbers. Then, the concepts of real and imaginary parts of complex numbers are explored, the complex conjugate is defined, and the pictorial representation of a complex number via Argand diagrams is explained.
#
# Initial definitions of complex numbers
#
# The key concept that separates complex numbers from real numbers is the existence of the imaginary unit, otherwise known as i;
#
# Definition of the imaginary unit
#
# The imaginary unit i is defined by the fact that i squared equals negative 1.
#
# Important
#
# Sometimes the imaginary unit is written by j instead of i. This is often used in contexts where i means something else, such as in engineering and in the programming language Python.
#
# Now, you can use the imaginary unit to define a complex number:
#
# Definition of a complex number
#
# Any number z equals a plus b i where a and b are real numbers is called a complex number.
#
# Tip
#
# The set of all complex numbers is called the complex numbers.
#
# Sometimes a complex number z equals a plus b i can be written as z equals a plus i b. This particularly happens when b is a square root such as the square root of 5, or the output of a function such as sine x.
#
# Example 1
#
# Here are some complex numbers: z sub 1 equals 1 plus 3 i, z sub 2 equals negative 4 plus 6 i, z sub 3 equals 8 divided by 3 minus 13 i divided by 5, z sub 4 equals negative pi minus i pi. Some more complex numbers are z sub 5 equals 0 plus 4 i equals 4 i and z sub 6 equals negative 2 plus 0 i equals negative 2.
#
# You can notice that in Example 1, z sub 5 and z sub 6 have a equals 0 and b equals 0 respectively. These are examples of some special kinds of complex numbers:
#
# If b equals 0, then z equals a is known as real number. So every real number is also a complex number.
#
# If a equals 0, then z equals b i is known as a purely imaginary number.
#
# Square roots of negative numbers
#
# You will notice that i is defined by the fact that i squared equals negative 1. It is very important to say that i is not the only solution to the equation x squared equals negative 1. Considering open paren negative i close paren squared and using the laws of indices (see Guide: Laws of indices) gives open paren negative i close paren squared equals open paren negative 1 times i close paren squared equals open paren negative 1 close paren squared times i squared equals 1 times negative 1 equals negative 1 and so negative i is also a solution to x squared equals negative 1.
#
# Purely imaginary numbers are used to express solutions to the equation x squared equals negative a, where a is greater than 0 is a positive real number.
#
# Solutions to x squared equals negative a
#
# Let a is greater than 0 be a positive real number. Then the solutions to x squared equals negative a are given by x equals i the square root of a and x equals negative i the square root of a period
#
# Example 2
#
# The two solutions of x squared equals negative 64 are x equals 8 i and x equals negative 8 i.
#
# The two solutions of x squared equals negative 3 are x equals i the square root of 3 and x equals negative i the square root of 3.
#
# Real and imaginary parts
#
# The real numbers a comma b that form the two separate parts of the complex number z equals a plus b i have special names. These real numbers can be recovered from the complex number by taking real and imaginary parts:
#
# Definition of real and imaginary parts
#
# If z equals a plus b i is a complex number, then:
#
# the real part real z of z is defined to be real z equals a,
#
# the imaginary part imaginary z of z is defined to be imaginary z equals b, the coefficient of i in z equals a plus b i.
#
# Sometimes, the real part of a complex number is written as normal fraktur cap R of z, and the imaginary part as normal fraktur cap I of z.
#
# Warning
#
# The real and imaginary parts of a complex number z equals a plus b i are real numbers, so your answer should not involve the imaginary unit.
#
# In this language, a complex number z is real if and only if imaginary z equals 0; a complex number z is purely imaginary if and only if real z equals 0.
#
# Example 3
#
# In Example 1, you saw six complex numbers z sub 1 to z sub 6. Here, their real and imaginary parts are given.
#
# The real part of z sub 1 equals 1 plus 3 i is the real of open paren z sub 1 close paren equals 1, and the imaginary part of z sub 1 is the imaginary of open paren z sub 1 close paren equals 3.
#
# The real part of z sub 2 equals negative 4 plus 6 i is the real of open paren z sub 2 close paren equals negative 4, and the imaginary part of z sub 2 is the imaginary of open paren z sub 2 close paren equals 6.
#
# The real part of z sub 3 equals 8 divided by 3 minus 13 i divided by 5 is the real of open paren z sub 3 close paren equals 8 divided by 3, and the imaginary part of z sub 3 is the imaginary of open paren z sub 3 close paren equals negative 13 divided by 5.
#
# The real part of z sub 4 equals negative pi minus i pi is the real of open paren z sub 4 close paren equals negative pi, and the imaginary part of z sub 4 is the imaginary of open paren z sub 4 close paren equals negative pi.
#
# The real part of z sub 5 equals 4 i is the real of open paren z sub 5 close paren equals 0, as z sub 5 equals 4 i equals 0 plus 4 i. The imaginary part of z sub 5 is the imaginary of open paren z sub 5 close paren equals 4.
#
# The real part of z sub 6 equals negative 2 is the real of open paren z sub 6 close paren equals negative 2. The imaginary part of z sub 6 is the imaginary of open paren z sub 6 close paren equals 0, as z sub 6 equals negative 2 equals negative 2 plus 0 i.
#
# The complex conjugate
#
# You saw in the previous section on square roots of negative numbers that the solutions to negative a squared are i the square root of a and negative i the square root of a, where a is a positive number. As it turns out, this is an example of a more general phenomenon known as the complex conjugate.
#
# Definition of the complex conjugate
#
# If z equals a plus b i is a complex number, then the complex conjugate z bar (or z raised to the asterisk power) of z is the complex number z bar equals a minus b i.
#
# So the complex conjugate of z equals a plus b i is the complex number with the same real part and with the sign of the imaginary part switched from either plus to minus or from minus to plus. Let’s take a look at some examples.
#
# Example 4
#
# In Example 1, you saw six complex numbers z sub 1 to z sub 6. Here, their complex conjugates are given.
#
# The complex conjugate of z sub 1 equals 1 plus 3 i is z bar sub 1 equals 1 minus 3 i.
#
# The complex conjugate of z sub 2 equals negative 4 plus 6 i is z bar sub 2 equals negative 4 minus 6 i.
#
# The complex conjugate of z sub 3 equals 8 divided by 3 minus 13 i divided by 5 is z bar sub 3 equals 8 divided by 3 plus 13 i divided by 5.
#
# The complex conjugate of z sub 4 equals negative pi minus i pi is z bar sub 4 equals negative pi plus i pi.
#
# The complex conjugate of z sub 5 equals 4 i is z bar sub 5 equals negative 4 i.
#
# The complex conjugate of z sub 6 equals negative 2 is z bar sub 6 equals negative 2. Notice that taking the complex conjugate of any real number gives that same real number again!
#
# You can see from Examples 2 and 3 (and the definition of complex conjugate) that if real z equals a then the real of open paren z bar close paren equals a, and if imaginary z equals b then the imaginary of open paren z bar close paren equals negative b.
#
# Argand diagrams
#
# Because every complex number is writable as a plus b i for a comma b is a member of the real numbers, you can express every complex number a plus b i as a point open paren a comma b close paren in two-dimensional space. Such a graph is known as an Argand diagram.
#
# An Argand diagram has two axes called the real and imaginary axes. The real axis takes the place of the x-axis and the imaginary axis takes the place of the y-axis. See Figure 1 for more.
#
# To draw a complex number on an Argand diagram, you can plot the complex number z equals a plus b i at the point open paren a comma b close paren equals open paren sans serif real z comma sans serif imaginary z close paren. See Figure 2 for a representation of z equals 2 plus i on an Argand diagram.
#
# Example 5
#
# In Example 1, you saw six complex numbers z sub 1 to z sub 6, and Example 3 demonstrated the real and imaginary parts of these.
#
# The real part of z sub 1 equals 1 plus 3 i is the real of open paren z sub 1 close paren equals 1, and the imaginary part of z sub 1 is the imaginary of open paren z sub 1 close paren equals 3, so this corresponds to the point open paren 1 comma 3 close paren.
#
# The real part of z sub 2 equals negative 4 plus 6 i is the real of open paren z sub 2 close paren equals negative 4, and the imaginary part of z sub 2 is the imaginary of open paren z sub 2 close paren equals 6. This corresponds to the point open paren negative 4 comma 6 close paren.
#
# The real part of z sub 3 equals 8 divided by 3 minus 13 i divided by 5 is the real of open paren z sub 3 close paren equals 8 divided by 3, and the imaginary part of z sub 3 is the imaginary of open paren z sub 3 close paren equals negative 13 divided by 5. This corresponds to the point open paren 8 divided by 3 comma negative 13 divided by 5 close paren on the plane.
#
# The real part of z sub 4 equals negative pi minus i pi is the real of open paren z sub 4 close paren equals negative pi, and the imaginary part of z sub 4 is the imaginary of open paren z sub 4 close paren equals negative pi. This corresponds to the point open paren negative pi comma negative pi close paren.
#
# The real part of z sub 5 equals 4 i is the real of open paren z sub 5 close paren equals 0, as z sub 5 equals 4 i equals 0 plus 4 i. The imaginary part of z sub 5 is the imaginary of open paren z sub 5 close paren equals 4. This corresponds to a point open paren 0 comma 4 close paren, on the y-axis.
#
# The real part of z sub 6 equals negative 2 is the real of open paren z sub 6 close paren equals negative 2. The imaginary part of z sub 6 is the imaginary of open paren z sub 6 close paren equals 0, as z sub 6 equals negative 2 equals negative 2 plus 0 i. This corresponds to open paren 2 comma 0 close paren on the x-axis.
#
# See Figure 3 for an Argand diagram.
#
# Quick check problems
#
# Give the real and imaginary parts of the following complex numbers: w sub 1 equals 3 plus 6 i, w sub 2 equals negative 5 minus 6 i, w sub 3 equals 8 minus i, w sub 4 equals 0, and w sub 5 equals x plus 5 i.
#
# Answers:
#
# the real of open paren w sub 1 close paren equals  and the imaginary of open paren w sub 1 close paren equals  .
#
# the real of open paren w sub 2 close paren equals  and the imaginary of open paren w sub 2 close paren equals  .
#
# the real of open paren w sub 3 close paren equals  and the imaginary of open paren w sub 3 close paren equals  .
#
# the real of open paren w sub 4 close paren equals  and the imaginary of open paren w sub 4 close paren equals  .
#
# the real of open paren w sub 5 close paren equals  and the imaginary of open paren w sub 5 close paren equals  .
#
# You are given three statements below. Decide whether they are true or false.
#
# The complex conjugate of any purely imaginary number is a real number. Answer:
# TRUE
# FALSE
#  .
#
# The complex conjugate of a minus b i is a plus b i for all real numbers a comma b. Answer:
# TRUE
# FALSE
#  .
#
# Any real number is also a complex number. Answer:
# TRUE
# FALSE
#  .
#
# Further reading
#
# For more questions on the subject, please go to Questions: Introduction to complex numbers.
#
# For how to add, subtract, multiply, and divide complex numbers, please go to Guide: Arithmetic on complex numbers.
#
# Version history

# %%
# INSTALLS GOOGLE TEXT TO SPEECH
# !pip install gtts

from gtts import gTTS
print("Processing...") # Just to ensure its running because generating an MP3 file takes time
# Read the text file
with open('text.txt', 'r') as file:
    text = file.read()

# Convert the text to speech
tts = gTTS(text)

# Save the speech as an MP3 file
tts.save('introtocomplexnumbers.mp3')

print("MP3 file has been made!")
# Out:
# zsh:1: command not found: pip
# Processing...
# MP3 file has been made!
